# %% [markdown]
# <a href="https://colab.research.google.com/github/Madevalo/jvd-k.z/blob/main/Task_One.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from numpy.linalg import svd
from sklearn.decomposition import TruncatedSVD,PCA
import matplotlib.pyplot as plot

# %%
pca = PCA(2)
t_svd = TruncatedSVD(2)

# %%
size = 100

# %% [markdown]
# Generate Dataset

# %%
data = {'Loc':np.random.normal(80,20,size),'Size':np.random.normal(80,20,size),'Mall_Near':np.random.normal(80,20,size),'Ambience':np.random.normal(80,20,size),'Rent':np.random.normal(80,20,size)}

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#            Loc        Size   Mall_Near   Ambience        Rent
# 0    73.190994   64.288348  121.238972  73.680250   69.924967
# 1    68.116017   72.817040   69.458413  84.350345   71.138211
# 2    79.535034  105.035688   93.994803  55.861842   40.041384
# 3    72.070989   73.221321  100.861478  65.249720   43.940268
# 4   114.781357   67.538980   68.895644  42.559081   99.936030
# ..         ...         ...         ...        ...         ...
# 95   91.245114  152.523654   62.931889  97.684221   36.324324
# 96  108.822367   99.113517   67.727207  95.626253  103.912232
# 97   79.611472  148.398143   73.778049  65.127507   54.308183
# 98   88.334210   68.975078   71.470745  60.427474   73.108689
# 99   73.489257   70.783661   98.976572  70.515362  118.044075
#
# [100 rows x 5 columns]

# %% [markdown]
# Drop Target

# %%
features=data.drop('Rent',axis=1)

# %%
features
# Out:
#            Loc        Size   Mall_Near   Ambience
# 0    73.190994   64.288348  121.238972  73.680250
# 1    68.116017   72.817040   69.458413  84.350345
# 2    79.535034  105.035688   93.994803  55.861842
# 3    72.070989   73.221321  100.861478  65.249720
# 4   114.781357   67.538980   68.895644  42.559081
# ..         ...         ...         ...        ...
# 95   91.245114  152.523654   62.931889  97.684221
# 96  108.822367   99.113517   67.727207  95.626253
# 97   79.611472  148.398143   73.778049  65.127507
# 98   88.334210   68.975078   71.470745  60.427474
# 99   73.489257   70.783661   98.976572  70.515362
#
# [100 rows x 4 columns]

# %% [markdown]
# Dataframe to numpy

# %%
features_array = features.to_numpy()

# %%
features_array
# Out:
# array([[ 73.19099441,  64.28834838, 121.23897189,  73.68025035],
#        [ 68.11601671,  72.81703982,  69.45841314,  84.35034451],
#        [ 79.53503379, 105.03568751,  93.99480276,  55.86184164],
#        [ 72.07098855,  73.22132073, 100.86147757,  65.24971956],
#        [114.78135681,  67.53898037,  68.89564404,  42.55908073],
#        [ 92.41152464, 118.47156186,  66.28147067,  86.53870833],
#        [ 72.53609007, 103.89775318, 115.84312388,  69.90152571],
#        [ 45.56716265,  99.36110714,  82.62576793,  48.93708676],
#        [ 57.05199731, 108.59391725,  66.0920344 ,  58.77602538],
#        [ 78.77605105,  62.26682802, 115.85290323,  63.82249853],
#        [ 68.47132933,  89.78068615, 110.22346898,  68.01631366],
#        [ 79.01482477,  92.46198927, 111.12900609,  54.49950069],
#        [ 47.62750511,  49.09264838,  71.22764883,  97.6805246 ],
#        [ 73.45328056,  94.17154677,  68.37171245,  66.18903666],
# ...

# %%
t_svd.fit_transform(features_array)
# Out:
# array([[ 1.66083829e+02, -3.80040337e+01],
#        [ 1.47336206e+02, -1.31432292e+00],
#        [ 1.67538850e+02,  1.33702288e+01],
#        [ 1.55720429e+02, -1.70076134e+01],
#        [ 1.46755820e+02,  4.02917696e+00],
#        [ 1.82121000e+02,  3.56749727e+01],
#        [ 1.81368482e+02, -3.88746807e+00],
#        [ 1.38716501e+02,  1.63902791e+01],
#        [ 1.45723882e+02,  3.22743982e+01],
#        [ 1.60241985e+02, -3.42190756e+01],
#        [ 1.68422293e+02, -1.08828627e+01],
#        [ 1.68760643e+02, -6.63698638e+00],
#        [ 1.32597618e+02, -2.34762174e+01],
#        [ 1.51311546e+02,  1.90442963e+01],
#        [ 1.53901733e+02, -3.06155981e+01],
#        [ 1.34986726e+02, -4.90403994e+01],
#        [ 1.81133659e+02, -5.69900308e-02],
#        [ 1.71814521e+02,  8.74906882e+00],
#        [ 1.59493706e+02, -3.22481428e+01],
#        [ 1.57883642e+02,  4.98220930e+01],
#        [ 1.51826737e+02, -1.06071526e+01],
#        [ 1.50708491e+02, -7.53552052e+00],
# ...

# %% [markdown]
# singular

# %%
pca.fit_transform(features_array)
# Out:
# array([[-2.88419379e+01,  2.22629567e+01],
#        [-6.85152598e+00, -1.25720493e+01],
#        [ 1.66196027e+01,  3.13934869e+01],
#        [-1.58088367e+01,  2.01138407e+01],
#        [-5.87500732e+00,  2.52101781e+01],
#        [ 4.18053537e+01, -4.25614166e+00],
#        [ 9.35985710e+00,  3.04416621e+01],
#        [ 7.15719083e+00,  2.63420433e+01],
#        [ 2.33847252e+01,  1.26500371e+01],
#        [-2.89734509e+01,  2.76778526e+01],
#        [-3.30613543e+00,  2.57449470e+01],
#        [-6.31842392e-02,  3.89439481e+01],
#        [-3.25383898e+01, -2.95070045e+01],
#        [ 1.30556484e+01,  6.60069285e+00],
#        [-2.81652026e+01, -2.02485316e+01],
#        [-5.46441601e+01, -2.50691113e+01],
#        [ 7.69344802e+00,  4.47973506e+01],
#        [ 1.22213624e+01,  3.08300266e+01],
#        [-2.74170938e+01,  1.46432794e+01],
#        [ 4.34423717e+01,  3.20661428e+01],
#        [-1.10449469e+01,  4.04871896e+00],
#        [-1.02455489e+01, -1.41893090e+01],
# ...

# %%
plot.plot(pca.explained_variance_ratio_)
plot.ylabel('Explained Variance')
plot.xlabel('Components')
plot.show()
